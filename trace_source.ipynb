# %%
import os

# %%
mypath = '/home/ccma/Dataset/OfficeHomeDataset_10072016'

for root, dirs, files in os.walk(mypath):
    print('root: ', root)
    print('  dirs :', dirs)
    print('  files: ', files)
# Out:
# root:  /home/ccma/Dataset/OfficeHomeDataset_10072016
#   dirs : ['Real World', 'Art', 'Clipart', 'Product']
#   files:  ['imagelist.txt', 'ImageInfo.csv']
# root:  /home/ccma/Dataset/OfficeHomeDataset_10072016/Real World
#   dirs : ['Trash_Can', 'Glasses', 'Pencil', 'Computer', 'Push_Pin', 'TV', 'Exit_Sign', 'Toys', 'Candles', 'Hammer', 'Knives', 'Ruler', 'Refrigerator', 'Paper_Clip', 'Bed', 'Oven', 'Couch', 'Sneakers', 'Shelf', 'ToothBrush', 'Bottle', 'Soda', 'Alarm_Clock', 'Printer', 'Eraser', 'Backpack', 'File_Cabinet', 'Notebook', 'Flowers', 'Drill', 'Bike', 'Keyboard', 'Marker', 'Calendar', 'Batteries', 'Flipflops', 'Kettle', 'Pen', 'Curtains', 'Spoon', 'Helmet', 'Postit_Notes', 'Telephone', 'Mouse', 'Calculator', 'Radio', 'Scissors', 'Clipboards', 'Sink', 'Speaker', 'Desk_Lamp', 'Fan', 'Chair', 'Mug', 'Folder', 'Fork', 'Screwdriver', 'Laptop', 'Table', 'Bucket', 'Webcam', 'Lamp_Shade', 'Mop', 'Monitor', 'Pan']
#   files:  []
# ...
